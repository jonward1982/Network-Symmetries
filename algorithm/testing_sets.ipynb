# %%
import OPPs
import OrbitRepresentatives as ORs
import math
import timeit
#import matplotlib.pyplot as plt

# %%
N = 70
alist = [[0] for x in range(N)]
alist[0] = [i for i in range(1, N)]
Gstar = OPPs.Graph(alist)
pi = [[0], [i for i in range(1, N)]]

# %%
Reps, tests, successes = ORs.OrbitRepresentatives(Gstar, pi, False)

# %%
# %load_ext line_profiler

# %%
# %lprun -f ORs.Automorphisms.OPPs.Partition.degree ORs.OrbitRepresentatives(Gstar, pi, False)
